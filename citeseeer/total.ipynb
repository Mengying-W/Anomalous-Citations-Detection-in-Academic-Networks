# %%
import csv
import pandas as pd
import random
import re
import time
import numpy as np
from tqdm import tqdm, trange

# %% [markdown]
# # papervec matrix

# %%
aper_2vec = []
print(len(aper_2vec))
# Out:
# 0

# %%
f_coauthor = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/coauthor/matrix/abstract2vec.txt')
lines = f_coauthor.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    aper_2vec.append(list[0:128])
    Xtemp_row += 1
f_coauthor.close()
print(len(aper_2vec))
# Out:
# 748

# %%
f_samejournal = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/samejournal/matrix/abstract2vec.txt')
lines = f_samejournal.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    aper_2vec.append(list[0:128])
    Xtemp_row += 1
f_samejournal.close()

# %%
f_irre = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/irrelevant/matrix/abstract2vec.txt')
lines = f_irre.readlines()
Xtemp_row = 0

for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    aper_2vec.append(list[0:128])
    Xtemp_row += 1
f_irre.close()
# Out:
# 253

# %%
allpaper2vec = []
allpaper2vec = np.zeros((1391,128))
for i in range(1391):
    for j in range(128):
        if 0<= i and i <236:
            allpaper2vec[i][j] = aper_2vec[i][j]
        elif 236<= i and i <274:
            allpaper2vec[i][j] = aper_2vec[i+512][j]
        elif 274<= i and i < 302:
            allpaper2vec[i][j] = aper_2vec[i+836][j]
        elif 302<= i and i < 582:
            allpaper2vec[i][j] = aper_2vec[i-66][j]
        elif 582<= i and i < 719:
            allpaper2vec[i][j] = aper_2vec[i+204][j]
        elif 719<= i and i < 832:
            allpaper2vec[i][j] = aper_2vec[i+447][j]
        elif 832<= i and i < 1064:
            allpaper2vec[i][j] = aper_2vec[i-548][j]
        elif 1064<= i and i < 1279:
            allpaper2vec[i][j] = aper_2vec[i-141][j]
        elif 1279<= i and i < 1391:
            allpaper2vec[i][j] = aper_2vec[i][j]

# %%
f=open(r"/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/total/matrix/abstract2vec.txt","w")

for line in allpaper2vec:
    for item in line:                                 
        f.write(str(item) + ' ')
    f.write('\n')
f.close()
# Out:
# [-0.04504992  0.16788466 -0.76144785  0.458379   -0.38843465 -0.13861041
#   0.44748193 -0.03783173 -1.5151823  -0.09257128 -0.3485569   0.5677914
#  -0.69700825 -0.34045723 -0.78032756  0.66143185  0.20728585  0.17254157
#  -0.4137334  -1.0363232  -0.18507996 -0.14321144  0.5582713  -0.48336264
#   0.9258566  -0.9503633  -0.35350612 -0.8689662  -0.03999109  0.53419095
#   1.5603375  -0.67685455  0.8960447   0.14924996  0.9245199  -1.1478761
#  -0.31565067 -0.6158347   0.74998933 -0.597778    0.23342408  0.4068757
#  -0.64519906  0.9221215   0.28508908 -0.53088355  0.3238949  -0.26406807
#   0.23847517 -0.48682836  0.13583784 -0.048505   -0.09735147  0.06597045
#   0.18209593 -0.58838034 -1.5832578  -0.44909996  0.8443021   0.1765992
#   0.40843272  0.9240845   0.23425736 -0.05504607 -0.7630974  -0.6782088
#   0.9866326   0.67549783 -0.02678342 -0.32184976  0.2006334   0.37822595
#   0.868996   -0.54300153 -0.5044134  -0.13669367  0.7136677  -0.1791163
# ...

# %% [markdown]
# # IF matrix

# %%
ifs = []
print(len(ifs))
# Out:
# 0

# %%
f_coauthor = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/coauthor/matrix/IFS.txt')
lines = f_coauthor.readlines()

Xtemp_row = 0
for line in lines:
    ifs.append(line)
    Xtemp_row += 1
f_coauthor.close()
print(len(ifs))
# Out:
# 292

# %%
f_samejournal = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/samejournal/matrix/IFS.txt')
lines = f_samejournal.readlines()

Xtemp_row = 0
for line in lines:
    ifs.append(line)
    Xtemp_row += 1
f_samejournal.close()
print(len(ifs))
# Out:
# 394

# %%
f_irrelevant = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/irrelevant/matrix/IFS.txt')
lines = f_irrelevant.readlines()

Xtemp_row = 0
for line in lines:
    ifs.append(line)
    Xtemp_row += 1
f_irrelevant.close()
print(len(ifs))
# Out:
# 518

# %%
f=open("/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/total/matrix/IFS.txt","w")
 
for line in ifs:
    f.write(str(line))
    #f.write('\n')
f.close()

# %% [markdown]
# # author credits matrix

# %%
credits = []
print(len(credits))
# Out:
# 0

# %%
f_coauthor = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/coauthor/matrix/authorcredit.txt')
lines = f_coauthor.readlines()

Xtemp_row = 0
for line in lines:
    credits.append(line)
    Xtemp_row += 1
f_coauthor.close()
print(len(credits))
# Out:
# 3398

# %%
f_samejournal = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/samejournal/matrix/authorcredit.txt')
lines = f_samejournal.readlines()

Xtemp_row = 0
for line in lines:
    credits.append(line)
    Xtemp_row += 1
f_samejournal.close()
print(len(credits))
# Out:
# 5964

# %%
f_irrelevant = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/irrelevant/matrix/authorcredit.txt')
lines = f_irrelevant.readlines()

Xtemp_row = 0
for line in lines:
    credits.append(line)
    Xtemp_row += 1
f_irrelevant.close()
print(len(credits))
# Out:
# 7489

# %%
f=open("/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/total/matrix/authorcredit.txt","w")
 
for line in credits:
    f.write(str(line))
    #f.write('\n')
f.close()

# %% [markdown]
# # journal paper matrix

# %%
coauthor_journalpaper = []
print(len(coauthor_journalpaper))

f_coauthor = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/coauthor/matrix/journalpaper.txt')
lines = f_coauthor.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    coauthor_journalpaper.append(list[0:748])
    Xtemp_row += 1
f_coauthor.close()
print(len(coauthor_journalpaper))
# Out:
# 0
# 292

# %%
samejournal_journalpaper = []
print(len(samejournal_journalpaper))

f_samejournal = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/samejournal/matrix/journalpaper.txt')
lines = f_samejournal.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    samejournal_journalpaper.append(list[0:390])
    Xtemp_row += 1
f_samejournal.close()
print(len(samejournal_journalpaper))
# Out:
# 0
# 102

# %%
irrelevant_journalpaper = []
print(len(irrelevant_journalpaper))

f_irrelevant = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/irrelevant/matrix/journalpaper.txt')
lines = f_irrelevant.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    irrelevant_journalpaper.append(list[0:253])
    Xtemp_row += 1
f_irrelevant.close()
print(len(irrelevant_journalpaper))
# Out:
# 0
# 124

# %%
journal_paper = np.zeros((518,1391))
for i in range(292):
    for j in range(1391):
        if 0<=j and j<236:
            journal_paper[i][j] = coauthor_journalpaper[i][j]
        elif 302<=j and j < 582:
            journal_paper[i][j] = coauthor_journalpaper[i][j-68]
        elif 832<=j and j < 1064:
            journal_paper[i][j] = coauthor_journalpaper[i][j-316]
for i in range(292,394):
    for j in range(1391):
        if 236<=j and j<274:
            journal_paper[i][j] = samejournal_journalpaper[i-292][j-236]
        elif 582<=j and j < 719:
            journal_paper[i][j] = samejournal_journalpaper[i-292][j-544]
        elif 1064<=j and j < 1279:
            journal_paper[i][j] = samejournal_journalpaper[i-292][j-889]
for i in range(394,518):
    for j in range(1391):
        if 274<=j and j<302:
            journal_paper[i][j] = irrelevant_journalpaper[i-394][j-274]
        elif 719<=j and j < 832:
            journal_paper[i][j] = irrelevant_journalpaper[i-394][j-691]
        elif 1279<=j and j < 1391:
            journal_paper[i][j] = irrelevant_journalpaper[i-394][j-1138]

# %%
f=open(r"/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/total/matrix/journalpaper.txt","w")
 
for line in journal_paper:
    for item in line:
        item = int(item)
        f.write(str(item)+ ' ')
    f.write('\n')
f.close()

# %% [markdown]
# # author author matrix

# %%
coauthor_aa = []
print(len(coauthor_aa))

f_coauthor = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/coauthor/matrix/authorauthor.txt')
lines = f_coauthor.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    coauthor_aa.append(list[0:3398])
    Xtemp_row += 1
f_coauthor.close()
print(len(coauthor_aa))
# Out:
# 0
# 3398

# %%
samejournal_aa = []
print(len(samejournal_aa))

f_coauthor = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/samejournal/matrix/authorauthor.txt')
lines = f_coauthor.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    samejournal_aa.append(list[0:2566])
    Xtemp_row += 1
f_coauthor.close()
print(len(samejournal_aa))
# Out:
# 0
# 2566

# %%
irrelevant_aa = []
print(len(irrelevant_aa))

f_coauthor = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/irrelevant/matrix/authorauthor.txt')
lines = f_coauthor.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    irrelevant_aa.append(list[0:1525])
    Xtemp_row += 1
f_coauthor.close()
print(len(irrelevant_aa))
# Out:
# 0
# 1525

# %%
author_author = np.zeros((7489,7489))
for i in range(3398):
    for j in range(3398):
        author_author[i][j] = coauthor_aa[i][j]
for i in range(3398,5964):
    for j in range(3398,5964):
        author_author[i][j] = samejournal_aa[i-3398][j-3398]
for i in range(5964,7489):
    for j in range(5964,7489):
        author_author[i][j] = irrelevant_aa[i-5964][j-5964]

# %%
f=open(r"/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/total/matrix/authorauthor.txt","w")
 
for line in author_author:
    for item in line:
        item = int(item)
        f.write(str(item)+ ' ')
    f.write('\n')
f.close()

# %% [markdown]
# # author- paper matrix

# %%
coauthor_ap = []
print(len(coauthor_ap))

f_coauthor = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/coauthor/matrix/authorpaper.txt')
lines = f_coauthor.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    coauthor_ap.append(list[0:748])
    Xtemp_row += 1
f_coauthor.close()
print(len(coauthor_ap))
# Out:
# 0
# 3398

# %%
samejournal_ap = []
print(len(samejournal_ap))

f_samejournal = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/samejournal/matrix/authorpaper.txt')
lines = f_samejournal.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    samejournal_ap.append(list[0:390])
    Xtemp_row += 1
f_samejournal.close()
print(len(samejournal_ap))
# Out:
# 0
# 2566

# %%
irrelevant_ap = []
print(len(irrelevant_ap))

f_irrelevant = open('/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/irrelevant/matrix/authorpaper.txt')
lines = f_irrelevant.readlines()

Xtemp_row = 0
for line in lines:
    list = re.sub(' +',' ',line.strip('\n').strip()).split(' ')
    irrelevant_ap.append(list[0:253])
    Xtemp_row += 1
f_irrelevant.close()
print(len(irrelevant_ap))
# Out:
# 0
# 1525

# %%
author_paper = np.zeros((7489,1391))
for i in range(3398):
    for j in range(1391):
        if 0<=j and j<236:
            author_paper[i][j] = coauthor_ap[i][j]
        elif 302<=j and j < 582:
            author_paper[i][j] = coauthor_ap[i][j-68]
        elif 832<=j and j < 1064:
            author_paper[i][j] = coauthor_ap[i][j-316]
for i in range(3398,5964):
    for j in range(1391):
        if 236<=j and j<274:
            author_paper[i][j] = samejournal_ap[i-3398][j-236]
        elif 582<=j and j < 719:
            author_paper[i][j] = samejournal_ap[i-3398][j-544]
        elif 1064<=j and j < 1279:
            author_paper[i][j] = samejournal_ap[i-3398][j-889]
for i in range(5964,7489):
    for j in range(1391):
        if 274<=j and j<302:
            author_paper[i][j] = irrelevant_ap[i-5964][j-274]
        elif 719<=j and j < 832:
            author_paper[i][j] = irrelevant_ap[i-5964][j-691]
        elif 1279<=j and j < 1391:
            author_paper[i][j] = irrelevant_ap[i-5964][j-1138]

# %%
f=open(r"/Users/carina/Downloads/刘嘉莹/异常引用补充实验/sourcecode/ANCI_code/dataset/data/total/matrix/authorpaper.txt","w")
 
for line in author_paper:
    for item in line:
        item = int(item)
        f.write(str(item)+ ' ')
    f.write('\n')
f.close()
